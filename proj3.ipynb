# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/svel2/Downloads/kidney_disease - kidney_disease.csv")

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df['classification'].value_counts()
# Out:
# classification
# ckd       250
# notckd    150
# Name: count, dtype: int64

# %%
df['sc']=df['sc'].fillna(0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for the column "su"
plt.figure(figsize=(8,5))
sns.histplot(df['su'], kde=True, bins=30)
plt.title("Histogram of 'su' Column")
plt.xlabel("su values")
plt.ylabel("Count")
plt.show()

# %%
df['su'] = df['su'].fillna(df['su'].mode()[0])

# %%
df['su'].value_counts().sum()
# Out:
# np.int64(400)

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['age'], kde=True, bins=30)
plt.title("Histogram of 'su' Column")
plt.xlabel("su values")
plt.ylabel("Count")
plt.show()

# %%
df['age'] = df['age'].fillna(df['age'].median())

# %%
df['sg'].value_counts()
# Out:
# sg
# 1.020    106
# 1.010     84
# 1.025     81
# 1.015     75
# 1.005      7
# Name: count, dtype: int64

# %%
df.head()
pd.set_option("display.max_columns",None)

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr    bu   sc    sod  pot  hemo pcv    wc   rc  htn   dm cad appet   pe  \
# 0  121.0  36.0  1.2    NaN  NaN  15.4  44  7800  5.2  yes  yes  no  good   no
# 1    NaN  18.0  0.8    NaN  NaN  11.3  38  6000  NaN   no   no  no  good   no
# 2  423.0  53.0  1.8    NaN  NaN   9.6  31  7500  NaN   no  yes  no  poor   no
# 3  117.0  56.0  3.8  111.0  2.5  11.2  32  6700  3.9  yes   no  no  poor  yes
# 4  106.0  26.0  1.4    NaN  NaN  11.6  35  7300  4.6   no   no  no  good   no
#
#    ane classification
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df['bp'].isnull().sum()
# Out:
# np.int64(12)

# %%
df['bp'] = df['bp'].fillna(df['bp'].median())

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['bp'], kde=True, bins=30)
plt.title("Histogram of 'su' Column")
plt.xlabel("su values")
plt.ylabel("Count")
plt.show()

# %%
df['bu'].isnull().sum()
# Out:
# np.int64(19)

# %%
df['bu'] = df['bu'].fillna(df['bu'].median())

# %%
df['hemo'] = df['hemo'].fillna(df['hemo'].median())

# %%
df['al'] = df['al'].fillna(df['al'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             400 non-null    float64
#  2   bp              400 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              400 non-null    float64
#  5   su              400 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              400 non-null    float64
#  12  sc              400 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            400 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.drop(
    ["id","sg","rbc","pc","pcc","ba","bgr","sod","pot","pcv","wc","rc",
     "htn","dm","cad","appet","pe","ane"],
    axis=1,
    inplace=True
)

# %%
df.head()
# Out:
#     age    bp   al   su    bu   sc  hemo classification
# 0  48.0  80.0  1.0  0.0  36.0  1.2  15.4            ckd
# 1   7.0  50.0  4.0  0.0  18.0  0.8  11.3            ckd
# 2  62.0  80.0  2.0  3.0  53.0  1.8   9.6            ckd
# 3  48.0  70.0  4.0  0.0  56.0  3.8  11.2            ckd
# 4  51.0  80.0  2.0  0.0  26.0  1.4  11.6            ckd

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             400 non-null    float64
#  1   bp              400 non-null    float64
#  2   al              400 non-null    float64
#  3   su              400 non-null    float64
#  4   bu              400 non-null    float64
#  5   sc              400 non-null    float64
#  6   hemo            400 non-null    float64
#  7   classification  400 non-null    object
# dtypes: float64(7), object(1)
# memory usage: 25.1+ KB

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
from sklearn.preprocessing import LabelEncoder

label_enc = LabelEncoder()

df['classification'] = label_enc.fit_transform(df['classification'])

# %%
df.head()
# Out:
#     age    bp   al   su    bu   sc  hemo  classification
# 0  48.0  80.0  1.0  0.0  36.0  1.2  15.4               0
# 1   7.0  50.0  4.0  0.0  18.0  0.8  11.3               0
# 2  62.0  80.0  2.0  3.0  53.0  1.8   9.6               0
# 3  48.0  70.0  4.0  0.0  56.0  3.8  11.2               0
# 4  51.0  80.0  2.0  0.0  26.0  1.4  11.6               0

# %%
df['classification'].value_counts()
# Out:
# classification
# 0    250
# 1    150
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#               age          bp         al          su          bu          sc  \
# count  400.000000  400.000000  400.00000  400.000000  400.000000  400.000000
# mean    51.562500   76.575000    0.90000    0.395000   56.693000    2.941875
# std     16.982996   13.489785    1.31313    1.040038   49.395258    5.651664
# min      2.000000   50.000000    0.00000    0.000000    1.500000    0.000000
# 25%     42.000000   70.000000    0.00000    0.000000   27.000000    0.900000
# 50%     55.000000   80.000000    0.00000    0.000000   42.000000    1.200000
# 75%     64.000000   80.000000    2.00000    0.000000   61.750000    2.725000
# max     90.000000  180.000000    5.00000    5.000000  391.000000   76.000000
#
#             hemo  classification
# count  400.00000      400.000000
# mean    12.54250        0.375000
# std      2.71649        0.484729
# min      3.10000        0.000000
# 25%     10.87500        0.000000
# 50%     12.65000        0.000000
# 75%     14.62500        1.000000
# ...

# %%
x = df.drop("classification",axis=1)
y = df['classification']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LogisticRegression

lr_mode=LogisticRegression()
lr_mode.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr_mode.score(x_test,y_test)
# Out:
# 0.95

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Example: true and predicted labels
y_pred = lr_mode.predict(x_test)

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix for Logistic Regression")
plt.show()

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix

y_hat = lr_mode.predict(x_test)

acc = accuracy_score(y_test,y_hat)
prec = precision_score(y_test,y_hat)
rec = recall_score(y_test,y_hat)
f1_score = f1_score(y_test,y_hat)

print(f"accuracy : {acc}")
print(f"precision : {prec}")
print(f"recall : {rec}")
print(f"f1_score : {f1_score}")
# Out:
# accuracy : 0.95
# precision : 0.8666666666666667
# recall : 1.0
# f1_score : 0.9285714285714286

# %%
import pickle

with open('kidney_model.pkl','wb') as f:
  pickle.dump(lr_mode,f)

with open('enc_kidney1.pkl','wb') as e:
  pickle.dump(label_enc,e)



with open('kidney_model.pkl','rb') as f:
  model_kid = pickle.load(f)

with open('enc_kidney1.pkl','rb') as e:
  kid_enc = pickle.load(e)
